# %%
import numpy as np
import os
import pandas as pd
from pandas import ExcelWriter
import matplotlib.pyplot as plt
import openpyxl
import matplotlib as mpl
import scipy as sp
from scipy import stats
from scipy import signal
from scipy import fft
from scipy import io
from scipy import interpolate
from scipy import optimize
from scipy import linalg
from scipy import integrate
from scipy.fft import dct

mpl.rcParams['text.usetex'] = True
mpl.rcParams['text.latex.preamble'] = [
    r'\usepackage{textcomp}',
    r'\usepackage{wasysym}']
mpl.rcParams['mathtext.fontset'] = 'stix'
mpl.rcParams['font.size'] = 22
mpl.rcParams['font.family'] = 'STIXGeneral'

from MEM_class import MEM

from synthData_Gen import SyntheticData_Gen

# %% [markdown]
# Generate a time series of synthetic data through an AR1 process:

# %%
#s1_instance = SyntheticData_Gen(AR1_coef = 0.3, AR1_var = 120, AR1_dt = 0.001, AR1_N = 20000, diff_len=0.08, dt_sample = 0.02, meas_noise = 0.03)
#s1 = s1_instance()

# %% [markdown]
# Plot said time series, both raw AR1 process and sampled/diffused series.

# %%
#plotFig = True
#if plotFig:
#    figSynth, axSynth = plt.subplots(figsize=(12,6))
#    axSynth.set(xlim=(0,20), xlabel='Depth [m]', ylabel='$\delta^{18}$O [\permil]')
#    axSynth.plot(s1[2],s1[3],linewidth=0.8, color='blue', alpha=0.9,label='Before diffusion')
#    axSynth.plot(s1[4],s1[5], color='black', label='After diffusion')
#    axSynth.legend()
#    figSynth.savefig('SynthData.png')

# %% [markdown]
# Plot only the sampled/diffused data.

# %%
#if plotFig:
#    figSynthDiff, axSynthDiff = plt.subplots(figsize=(12,6))
#    axSynthDiff.set(xlim=(0,20), xlabel='Depth [m]', ylabel='$\delta^{18}$O [\permil]', title='Synthetic data, after diffusion')
#    axSynthDiff.plot(s1[4],s1[5], color='black')
#

# %% [markdown]
# Define depth and signal data from synthetic data. Create an instance of a signal to use for spectral analysis.

# %%
data = pd.read_csv('../Data/datasets/Alphabet_cores/crete_det.txt', ' ')
plt.plot(data['depth'], data['d18O'])

# %%
valMin = 50
valMax = 60

d18O_U = data['d18O'][(data['depth'] > valMin) & (data['depth'] < valMax)]
d18O = d18O_U - np.mean(d18O_U)
dep = data['depth'][(data['depth'] > valMin) & (data['depth'] < valMax)]
plt.plot(dep, d18O)

# %%
depth = np.asarray(dep)#s1[4]#
data = np.asarray(d18O)#s1[5]#
dt = depth[1] - depth[0]
N = data.size
sigma_in = 0.08

# %%
from Decon import SpectralDecon
decon_inst = SpectralDecon(depth, data, 5000)

# %%
decon_inst.plotSpectrum()
# Out:
# Using default boundaries for variance and a1
# Fit Parameters:
#
# P0 = 0.25767449755112437
# Var = 0.08722031708134816
# s_eta2 = 0.08722031708134816 m
# Diff len = 8.23290965686658 cm
# a1 = 0.1965220897661599
# Diff. len., fit [cm]: 8.233

# %%
decon_inst.plotFilters(sigma=sigma_in)
# Out:
# Using default boundaries for variance and a1
# Fit Parameters:
#
# P0 = 0.25767449755112437
# Var = 0.08722031708134816
# s_eta2 = 0.08722031708134816 m
# Diff len = 8.23290965686658 cm
# a1 = 0.1965220897661599
# Diff. len., fit [cm]: 8.233
# (<matplotlib.figure.Figure at 0x7ff372ff68d0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7ff373084518>)

# %%
decon_inst.plotDecon(sigma=sigma_in)
# Out:
# Using default boundaries for variance and a1
# Fit Parameters:
#
# P0 = 0.25767449755112437
# Var = 0.08722031708134816
# s_eta2 = 0.08722031708134816 m
# Diff len = 8.23290965686658 cm
# a1 = 0.1965220897661599
# Diff. len., fit [cm]: 8.233
# (<matplotlib.figure.Figure at 0x7ff372f53da0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7ff372f6dfd0>)
