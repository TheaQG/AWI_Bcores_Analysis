# %%
import numpy as np
import os
import pandas as pd
from pandas import ExcelWriter
import matplotlib.pyplot as plt
import openpyxl
import matplotlib as mpl
import scipy as sp
from scipy import stats
from scipy import signal
from scipy import fft
from scipy import io
from scipy import interpolate
from scipy import optimize
from scipy import linalg
from scipy import integrate
from scipy.fft import dct

mpl.rcParams['text.usetex'] = True
mpl.rcParams['text.latex.preamble'] = [
    r'\usepackage{textcomp}',
    r'\usepackage{wasysym}']
mpl.rcParams['mathtext.fontset'] = 'stix'
mpl.rcParams['font.size'] = 22
mpl.rcParams['font.family'] = 'STIXGeneral'

saveFigs = False

# %%
import sys 
import os
sys.path.append('../')

from BackDiffuse_LT import BackDiffuse
from GetCoreData_fct import GetCoreData



from Interpolation_Class import Interpolation

# %%
CoresSpecs = pd.read_csv('/home/thea/Documents/KUFysik/MesterTesen/Data/CoreSpecs.txt', ',')

coreNames = CoresSpecs['CoreName']

# %%
site = 'SiteG'

core_idx = coreNames[CoresSpecs['CoreName'] == site].index[0]
CoreSpecs = CoresSpecs.iloc[core_idx]
dTamb = CoreSpecs['dTamb']
dLaki = CoreSpecs['dLaki']


DataAll = GetCoreData(site)

data_d18O = DataAll[0]; data_d18O_LT = DataAll[1]
data_ECM = DataAll[2]; data_ECM_LT = DataAll[3]
data_dens = DataAll[4]; data_dens_LT = DataAll[5]
data_diff = DataAll[6]; data_diff_LT = DataAll[7]


depth_LT = data_d18O_LT['depth']
d18O_LT = data_d18O_LT['d18O']

# %%
delta_arr = np.arange(0.004,0.065,0.0005)
diffLens = []
depths = []
datas = []
peakss = [] 

delta_arr
# Out:
# array([0.004 , 0.0045, 0.005 , 0.0055, 0.006 , 0.0065, 0.007 , 0.0075,
#        0.008 , 0.0085, 0.009 , 0.0095, 0.01  , 0.0105, 0.011 , 0.0115,
#        0.012 , 0.0125, 0.013 , 0.0135, 0.014 , 0.0145, 0.015 , 0.0155,
#        0.016 , 0.0165, 0.017 , 0.0175, 0.018 , 0.0185, 0.019 , 0.0195,
#        0.02  , 0.0205, 0.021 , 0.0215, 0.022 , 0.0225, 0.023 , 0.0235,
#        0.024 , 0.0245, 0.025 , 0.0255, 0.026 , 0.0265, 0.027 , 0.0275,
#        0.028 , 0.0285, 0.029 , 0.0295, 0.03  , 0.0305, 0.031 , 0.0315,
#        0.032 , 0.0325, 0.033 , 0.0335, 0.034 , 0.0345, 0.035 , 0.0355,
#        0.036 , 0.0365, 0.037 , 0.0375, 0.038 , 0.0385, 0.039 , 0.0395,
#        0.04  , 0.0405, 0.041 , 0.0415, 0.042 , 0.0425, 0.043 , 0.0435,
#        0.044 , 0.0445, 0.045 , 0.0455, 0.046 , 0.0465, 0.047 , 0.0475,
#        0.048 , 0.0485, 0.049 , 0.0495, 0.05  , 0.0505, 0.051 , 0.0515,
#        0.052 , 0.0525, 0.053 , 0.0535, 0.054 , 0.0545, 0.055 , 0.0555,
#        0.056 , 0.0565, 0.057 , 0.0575, 0.058 , 0.0585, 0.059 , 0.0595,
#        0.06  , 0.0605, 0.061 , 0.0615, 0.062 , 0.0625, 0.063 , 0.0635,
#        0.064 , 0.0645])

# %%
inst = BackDiffuse(site, data_d18O_LT, CoresSpecs, dTamb, dLaki, 32, diffLenData=data_diff_LT[['Depth','sigma_o18']], densData=data_dens_LT)
diffLen = inst.spectralEstimate()
difflenEstHL = inst.diffLenEstimateHL()
depth1, data, diffLen, peaks, arr_DiffLens, arr_Npeaks, arr_depth, arr_data = inst.backDiffused(theoDiffLen=True,print_Npeaks=False, diffLenStart_In=0.005, diffLenEnd_In=0.15, interpAfterDecon=True, newDelta=0.02)
# Out:
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.42 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.020

# %%
for i in range(len(delta_arr)):
    depth1, data, diffLen, peaks, arr_DiffLens, arr_Npeaks, arr_depth, arr_data = inst.backDiffused(theoDiffLen=True,print_Npeaks=False, diffLenStart_In=0.005, diffLenEnd_In=0.15, interpAfterDecon=True, newDelta=delta_arr[i])
    depths.append(depth1)
    datas.append(data)
    diffLens.append(diffLen)
# Out:
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.40 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.004
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.40 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.005
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.40 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.005
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.40 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.006
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.40 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.006
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.40 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.007
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.41 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.007
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.40 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.008
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.40 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.008
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.40 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.009
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.41 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.009
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.41 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.010
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.40 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.010
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.41 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.011
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.40 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.011
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.42 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.012
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.42 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.012
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.41 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.013
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.42 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.013
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.42 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.014
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.43 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.014
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.41 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.015
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.43 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.015
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.45 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.016
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.46 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.016
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.42 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.017
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.42 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.017
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.42 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.018
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.42 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.018
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.46 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.019
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.42 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.019
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.45 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.020
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.42 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.020
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.48 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.021
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.43 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.021
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.43 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.022
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.44 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.022
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.47 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.023
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.51 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.023
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.44 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.024
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.669 cm
# Final sigma: 8.52 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.024
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.48 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.025
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.53 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.025
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.669 cm
# Final sigma: 8.46 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.026
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.45 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.026
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.56 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.027
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.50 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.027
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.54 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.028
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.45 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.028
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.47 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.029
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.47 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.029
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.47 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.030
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.669 cm
# Final sigma: 8.46 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.030
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.50 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.031
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.58 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.031
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.61 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.032
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.59 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.032
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.55 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.033
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.52 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.033
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.50 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.034
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.669 cm
# Final sigma: 8.53 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.034
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.669 cm
# Final sigma: 8.62 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.035
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.669 cm
# Final sigma: 8.50 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.035
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.56 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.036
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.49 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.036
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.669 cm
# Final sigma: 8.50 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.037
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# 200. Npeaks: 32, diffLen: 8.668 cm
# Final sigma: 8.67 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.037
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.51 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.038
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.669 cm
# Final sigma: 8.52 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.038
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# 200. Npeaks: 32, diffLen: 8.668 cm
# Final sigma: 8.66 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.039
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.668 cm
# Final sigma: 8.61 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.039
# Starting sigma: 6.66 [cm]
# Final sigma: 7.63 [cm]
# Final # of peaks: 31
# Delta: 0.040
# Delta new: 0.040
# Starting sigma: 6.66 [cm]
# Final sigma: 7.61 [cm]
# Final # of peaks: 31
# Delta: 0.040
# Delta new: 0.040
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.669 cm
# Final sigma: 8.63 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.041
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 32, diffLen: 7.669 cm
# Final sigma: 8.50 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.041
# Starting sigma: 6.66 [cm]
# Final sigma: 7.58 [cm]
# Final # of peaks: 31
# Delta: 0.040
# Delta new: 0.042
# Starting sigma: 6.66 [cm]
# Final sigma: 7.56 [cm]
# Final # of peaks: 31
# Delta: 0.040
# Delta new: 0.042
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 31, diffLen: 7.669 cm
# Final sigma: 8.51 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.043
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 30, diffLen: 7.669 cm
# Final sigma: 7.65 [cm]
# Final # of peaks: 30
# Delta: 0.040
# Delta new: 0.043
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 31, diffLen: 7.669 cm
# Final sigma: 8.51 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.044
# Starting sigma: 6.66 [cm]
# Final sigma: 7.58 [cm]
# Final # of peaks: 30
# Delta: 0.040
# Delta new: 0.044
# Starting sigma: 6.66 [cm]
# Final sigma: 7.59 [cm]
# Final # of peaks: 31
# Delta: 0.040
# Delta new: 0.045
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 31, diffLen: 7.669 cm
# 200. Npeaks: 32, diffLen: 8.670 cm
# Final sigma: 8.93 [cm]
# Final # of peaks: 32
# Delta: 0.040
# Delta new: 0.045
# Starting sigma: 6.66 [cm]
# 100. Npeaks: 31, diffLen: 7.669 cm
# Final sigma: 7.71 [cm]
# Final # of peaks: 30
# Delta: 0.040
# Delta new: 0.046
# Starting sigma: 6.66 [cm]

# %%
fig, ax = plt.subplots(figsize=(14,6))

plt.plot(depth1,data, '-', marker='.',label='Back Diffused')
plt.plot(data_d18O_LT['depth'], data_d18O_LT['d18O']- np.mean(data_d18O_LT['d18O']),'-',marker='.', label='Data')
plt.plot(depth1[peaks],data[peaks],'.', color='k', ms=10, label='Peaks')
plt.title(site)
plt.legend(fontsize=12)

# %%
plt.plot(delta_arr,diffLens)
