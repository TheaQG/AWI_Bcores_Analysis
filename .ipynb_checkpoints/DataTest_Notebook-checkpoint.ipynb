# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import csv

path = "../Data/datasets/B_cores_AWI/"
filename = "NGT_d18O_highres.xlsx"

NGT_d18O_highres_data = pd.read_excel(path + filename, sheet_name=None)

# %%
class Cores():
    def __init__(self):
        pass
        return

# %%
headers = list(NGT_d18O_highres_data.keys())

df_B16_d18O = NGT_d18O_highres_data[headers[0]]
df_B17_d18O = NGT_d18O_highres_data[headers[1]]
df_B18_d18O = NGT_d18O_highres_data[headers[2]]
df_B19_d18O = NGT_d18O_highres_data[headers[3]]
df_B20_d18O = NGT_d18O_highres_data[headers[4]]
df_B21_d18O = NGT_d18O_highres_data[headers[5]]
df_B22_d18O = NGT_d18O_highres_data[headers[6]]
df_B23_d18O = NGT_d18O_highres_data[headers[7]]
df_B26_d18O = NGT_d18O_highres_data[headers[8]]
df_B27_d18O = NGT_d18O_highres_data[headers[9]]
df_B28_d18O = NGT_d18O_highres_data[headers[10]]
df_B29_d18O = NGT_d18O_highres_data[headers[11]]
df_B30_d18O = NGT_d18O_highres_data[headers[12]]

# %%
coreNames_d18O = ['B16', 'B17', 'B18', 'B19', 'B20', 'B21', 'B22', 'B23', 'B26', 'B27', 'B28', 'B29', 'B30']

f_d18O_save = 'Depth_d18O__Bcores.xlsx'
writer = pd.ExcelWriter(f_d18O_save, engine='xlsxwriter')
writer.save()

df16_d18O = pd.DataFrame({'depth': df_B16_d18O[df_B16_d18O.keys()[0]], 'd18O': df_B16_d18O[df_B16_d18O.keys()[2]]})
writer = pd.ExcelWriter(f_d18O_save, engine='openpyxl')
df16_d18O.to_excel(writer, sheet_name=coreNames_d18O[0], index=False)
writer.save()

df17_d18O = pd.DataFrame({'depth': df_B17_d18O[df_B17_d18O.keys()[0]], 'd18O': df_B17_d18O[df_B17_d18O.keys()[2]]})
df18_d18O = pd.DataFrame({'depth': df_B18_d18O[df_B18_d18O.keys()[1]], 'd18O': df_B18_d18O[df_B18_d18O.keys()[3]]})
df19_d18O = pd.DataFrame({'depth': df_B19_d18O[df_B19_d18O.keys()[0]], 'd18O': df_B19_d18O[df_B19_d18O.keys()[2]]})
df20_d18O = pd.DataFrame({'depth': df_B20_d18O[df_B20_d18O.keys()[1]], 'd18O': df_B20_d18O[df_B20_d18O.keys()[3]]})
df21_d18O = pd.DataFrame({'depth': df_B21_d18O[df_B21_d18O.keys()[0]], 'd18O': df_B21_d18O[df_B21_d18O.keys()[2]]})
df22_d18O = pd.DataFrame({'depth': df_B22_d18O[df_B22_d18O.keys()[0]], 'd18O': df_B22_d18O[df_B22_d18O.keys()[2]]})
df23_d18O = pd.DataFrame({'depth': df_B23_d18O[df_B23_d18O.keys()[0]], 'd18O': df_B23_d18O[df_B23_d18O.keys()[2]]})
df26_d18O = pd.DataFrame({'depth': df_B26_d18O[df_B26_d18O.keys()[0]], 'd18O': df_B26_d18O[df_B26_d18O.keys()[2]]})
df27_d18O = pd.DataFrame({'depth': df_B27_d18O[df_B27_d18O.keys()[0]], 'd18O': df_B27_d18O[df_B27_d18O.keys()[1]]})
df28_d18O = pd.DataFrame({'depth': df_B28_d18O[df_B28_d18O.keys()[0]], 'd18O': df_B28_d18O[df_B28_d18O.keys()[2]]})
df29_d18O = pd.DataFrame({'depth': df_B29_d18O[df_B29_d18O.keys()[0]], 'd18O': df_B29_d18O[df_B29_d18O.keys()[2]]})
df30_d18O = pd.DataFrame({'depth': df_B30_d18O[df_B30_d18O.keys()[0]], 'd18O': df_B30_d18O[df_B30_d18O.keys()[2]]})

with pd.ExcelWriter(f_d18O_save, engine='openpyxl', mode='a') as writer:
    df17_d18O.to_excel(writer, sheet_name=coreNames_d18O[1], index=False)
    df18_d18O.to_excel(writer, sheet_name=coreNames_d18O[2], index=False)
    df19_d18O.to_excel(writer, sheet_name=coreNames_d18O[3], index=False)
    df20_d18O.to_excel(writer, sheet_name=coreNames_d18O[4], index=False)
    df21_d18O.to_excel(writer, sheet_name=coreNames_d18O[5], index=False)
    df22_d18O.to_excel(writer, sheet_name=coreNames_d18O[6], index=False)
    df23_d18O.to_excel(writer, sheet_name=coreNames_d18O[7], index=False)
    df26_d18O.to_excel(writer, sheet_name=coreNames_d18O[8], index=False)
    df27_d18O.to_excel(writer, sheet_name=coreNames_d18O[9], index=False)
    df28_d18O.to_excel(writer, sheet_name=coreNames_d18O[10], index=False)
    df29_d18O.to_excel(writer, sheet_name=coreNames_d18O[11], index=False)
    df30_d18O.to_excel(writer, sheet_name=coreNames_d18O[12], index=False)

# %%
fig, ax = plt.subplots(figsize=(15,5))

ax.plot(df_B16_d18O[df_B16_d18O.keys()[0]], df_B16_d18O[df_B16_d18O.keys()[2]], alpha=0.7, label='B16')
#ax.plot(df_B17_d18O[df_B17_d18O.keys()[-1]], df_B17_d18O[df_B17_d18O.keys()[2]], alpha=0.7, label='B17')
#ax.plot(df_B18_d18O[df_B18_d18O.keys()[1]], df_B18_d18O[df_B18_d18O.keys()[3]], alpha=0.7, label='B18')
#ax.plot(df_B19_d18O[df_B19_d18O.keys()[0]], df_B19_d18O[df_B19_d18O.keys()[2]], alpha=0.7, label='B19')
#ax.plot(df_B20_d18O[df_B20_d18O.keys()[1]], df_B20_d18O[df_B20_d18O.keys()[3]], alpha=0.7, label='B20')
#ax.plot(df_B21_d18O[df_B21_d18O.keys()[0]], df_B21_d18O[df_B21_d18O.keys()[2]], alpha=0.7, label='B21')
#ax.plot(df_B22_d18O[df_B22_d18O.keys()[0]], df_B22_d18O[df_B22_d18O.keys()[2]], alpha=0.7, label='B22')
#ax.plot(df_B23_d18O[df_B23_d18O.keys()[0]], df_B23_d18O[df_B23_d18O.keys()[2]], alpha=0.7, label='B23')
#ax.plot(df_B26_d18O[df_B26_d18O.keys()[0]], df_B26_d18O[df_B26_d18O.keys()[2]], alpha=0.7, label='B26')
#ax.plot(df_B27_d18O[df_B27_d18O.keys()[0]], df_B27_d18O[df_B27_d18O.keys()[1]], alpha=0.7, label='B27')
#ax.plot(df_B28_d18O[df_B28_d18O.keys()[0]], df_B28_d18O[df_B28_d18O.keys()[2]], alpha=0.7, label='B28')
#ax.plot(df_B29_d18O[df_B29_d18O.keys()[0]], df_B29_d18O[df_B29_d18O.keys()[2]], alpha=0.7, label='B29')
#ax.plot(df_B30_d18O[df_B30_d18O.keys()[0]], df_B30_d18O[df_B30_d18O.keys()[2]], alpha=0.7, label='B30')
ax.legend(loc='best')
ax.set(xlabel='Depth [m]', ylabel='delta O18', xlim=(0,40))
# Out:
# [Text(0,0.5,'delta O18'), (0, 40), Text(0.5,0,'Depth [m]')]

# %%
path2 = "../Data/datasets/B_cores_AWI/"
filename2 = "chemistry_conductivity_NGT93_95_all.xlsx"

B_Cores_chem_cond__data = pd.read_excel(path2 + filename2, sheet_name=None)

# %%
df_B16_chem = B_Cores_chem_cond__data[headers2[0]]
df_B16_ECM = B_Cores_chem_cond__data[headers2[1]]
df_B17_DEP = B_Cores_chem_cond__data[headers2[2]]
df_B18_chem = B_Cores_chem_cond__data[headers2[3]]
df_B18_DEP = B_Cores_chem_cond__data[headers2[4]]
df_B18_ECM = B_Cores_chem_cond__data[headers2[5]]
df_B19_DEP = B_Cores_chem_cond__data[headers2[6]]
df_B20_DEP = B_Cores_chem_cond__data[headers2[7]]
df_B21_ECM = B_Cores_chem_cond__data[headers2[8]]
df_B21_chem = B_Cores_chem_cond__data[headers2[9]]
df_B22_DEP = B_Cores_chem_cond__data[headers2[10]]
df_B23_DEP = B_Cores_chem_cond__data[headers2[11]]
df_B26_DEP = B_Cores_chem_cond__data[headers2[12]]
df_B27_DEP = B_Cores_chem_cond__data[headers2[13]]
df_B28_DEP = B_Cores_chem_cond__data[headers2[14]]
df_B29_chem = B_Cores_chem_cond__data[headers2[15]]

# %%
fig_ECM1, ax_ECM1 = plt.subplots(figsize=(15,5))
ax_ECM1.set(xlabel='Depth [m]', ylabel='ECM')

#ax_ECM1.plot(df_B16_ECM[df_B16_ECM.keys()[0]], df_B16_ECM[df_B16_ECM.keys()[-1]], alpha=0.7, label='B16')
ax_ECM1.plot(df_B18_ECM[df_B18_ECM.keys()[1]], df_B18_ECM[df_B18_ECM.keys()[0]], alpha=0.7, label='B18')
#ax_ECM1.plot(df_B21_ECM[df_B21_ECM.keys()[5]], df_B21_ECM[df_B21_ECM.keys()[-1]], alpha=0.7, label='B21')
ax_ECM1.legend()

fig_ECM2, ax_ECM2 = plt.subplots(figsize=(15,5))
ax_ECM2.set(xlabel='Depth [m]', ylabel='ECM rho')
ax_ECM2.plot(df_B16_ECM[df_B16_ECM.keys()[5]], df_B16_ECM[df_B16_ECM.keys()[-2]], alpha=0.7, label='B16')
ax_ECM2.plot(df_B21_ECM[df_B21_ECM.keys()[5]], df_B21_ECM[df_B21_ECM.keys()[-2]], alpha=0.7, label='B21')
ax_ECM2.legend()

# %%
fig_DEP1a, ax_DEP1a = plt.subplots(figsize=(15,5))
ax_DEP1a.set(xlabel='Depth [m]', ylabel='g 250k', title='DEP 1a')
ax_DEP1a.plot(df_B17_DEP[df_B17_DEP.keys()[0]], df_B17_DEP[df_B17_DEP.keys()[1]], alpha=0.7, label='B17')
ax_DEP1a.plot(df_B18_DEP[df_B18_DEP.keys()[0]], df_B18_DEP[df_B18_DEP.keys()[5]], alpha=0.7, label='B18')
ax_DEP1a.plot(df_B19_DEP[df_B19_DEP.keys()[0]], df_B19_DEP[df_B19_DEP.keys()[1]], alpha=0.7, label='B19')
ax_DEP1a.legend(loc='best')

fig_DEP1b, ax_DEP1b = plt.subplots(figsize=(15,5))
ax_DEP1b.set(xlabel='Depth [m]', ylabel='cp 250k', title='DEP 1b')
ax_DEP1b.plot(df_B17_DEP[df_B17_DEP.keys()[0]], df_B17_DEP[df_B17_DEP.keys()[2]], alpha=0.7, label='B17')
ax_DEP1b.plot(df_B18_DEP[df_B18_DEP.keys()[0]], df_B18_DEP[df_B18_DEP.keys()[6]], alpha=0.7, label='B18')
ax_DEP1b.plot(df_B19_DEP[df_B19_DEP.keys()[0]], df_B19_DEP[df_B19_DEP.keys()[2]], alpha=0.7, label='B19')
ax_DEP1b.legend(loc='best')

# %%
#fig_DEP2a, ax_DEP2a = plt.subplots(figsize=(15,5))
#ax_DEP2a.set(xlabel='Depth [m]', ylabel='density', title='DEP 2a')
#ax_DEP2a.plot(df_B20_DEP[df_B20_DEP.keys()[0]], df_B20_DEP[df_B20_DEP.keys()[1]], alpha=0.7, label='B20')
#ax_DEP2a.plot(df_B22_DEP[df_B22_DEP.keys()[0]], df_B22_DEP[df_B22_DEP.keys()[1]], alpha=0.7, label='B22')
#ax_DEP2a.plot(df_B23_DEP[df_B23_DEP.keys()[0]], df_B23_DEP[df_B23_DEP.keys()[1]], alpha=0.7, label='B23')
#ax_DEP2a.legend(loc='best')

fig_DEP2b, ax_DEP2b = plt.subplots(figsize=(15,5))
ax_DEP2b.set(xlabel='Depth [m]', ylabel='conductivity', title='DEP 2b')
ax_DEP2b.plot(df_B20_DEP[df_B20_DEP.keys()[0]], df_B20_DEP[df_B20_DEP.keys()[2]], alpha=0.7, label='B20')
ax_DEP2b.plot(df_B22_DEP[df_B22_DEP.keys()[0]], df_B22_DEP[df_B22_DEP.keys()[2]], alpha=0.7, label='B22')
ax_DEP2b.plot(df_B23_DEP[df_B23_DEP.keys()[0]], df_B23_DEP[df_B23_DEP.keys()[2]], alpha=0.7, label='B23')
ax_DEP2b.legend(loc='best')

# %%
fig_DEP3a, ax_DEP3a = plt.subplots(figsize=(15,5))
ax_DEP3a.set(xlabel='Depth [m]', ylabel='sig 250k', title='DEP 3a')
ax_DEP3a.plot(df_B26_DEP[df_B26_DEP.keys()[1]], df_B26_DEP[df_B26_DEP.keys()[2]], alpha=0.7, label='B26')
ax_DEP3a.plot(df_B27_DEP[df_B27_DEP.keys()[0]], df_B27_DEP[df_B27_DEP.keys()[1]], alpha=0.7, label='B27')
ax_DEP3a.plot(df_B28_DEP[df_B28_DEP.keys()[0]], df_B28_DEP[df_B28_DEP.keys()[1]], alpha=0.7, label='B28')
ax_DEP3a.legend(loc='best')

fig_DEP3b, ax_DEP3b = plt.subplots(figsize=(15,5))
ax_DEP3b.set(xlabel='Depth [m]', ylabel='sig 250k corr', title='DEP 3b')
ax_DEP3b.plot(df_B26_DEP[df_B26_DEP.keys()[1]], df_B26_DEP[df_B26_DEP.keys()[0]], alpha=0.7, label='B26')
ax_DEP3b.plot(df_B27_DEP[df_B27_DEP.keys()[0]], df_B27_DEP[df_B27_DEP.keys()[3]], alpha=0.7, label='B27')
ax_DEP3b.plot(df_B28_DEP[df_B28_DEP.keys()[0]], df_B28_DEP[df_B28_DEP.keys()[3]], alpha=0.7, label='B28')
ax_DEP3b.legend(loc='best')
